# %% [markdown]
# # <center>Metody Numeryczne</center>
#
# # Laboratorium 8: Rozwiązywanie równań nieliniowych
#
#
# **Wykonał:** \<imię i nazwisko\>
#
# <br>
#
# ### **Metoda zaliczenia:**
#
# Podczas zajęć należy wykonać poniższe polecenia oraz udzielić odpowiedzi na pytania zamieszczone w treści zadań.
#
# Wszystkie funkcje wymagane w ramach ćwiczenia należy zaimplementować w pliku `main.py`. Poprawność ich działania należy zweryfikować za pomocą testów jednostkowych dostępnych w pliku `test_main.py`.
#
# ### **Cel zajęć:**
#
# Celem zajęć jest poznanie numerycznych metod rozwiązywania układów równań nieliniowych. W ramach laboratorium przedstawione zostaną metody: [*bisekcji*](https://www.wikiwand.com/pl/articles/Metoda_r%C3%B3wnego_podzia%C5%82u), [*siecznych*](https://www.wikiwand.com/pl/articles/Metoda_siecznych) oraz [*Newtona*](https://www.wikiwand.com/pl/articles/Metoda_Newtona).
#
# Tematem wiodącym podczas tych zajęć będzie poszukiwanie miejsc zerowych funkcji zdefiniowanej w następujący sposób:
# $$
# f(x) = e^{-2x} + x^2 - 1
# $$
#
# Funkcja $f(x)$ oraz jej pierwsza i druga pochodna ($f'(x)$, $f''(x)$) zostały zaimplementowane w pliku `main.py`, odpowiednio jako `func()`, `dfunc()` i `ddfunc()`.
#
# ### **Uwagi wstępne:**
# - Funkcje wymagające implementacji (lub zaimplementowane na poprzednich laboratoriach) oznaczone są pochyłą czcionką maszynową (np. *`my_func()`*).
#
# - W skrypcie stosuje się następujące skróty:
#
#     - `np` - `numpy`,
#     - `sp` - `scipy`.

# %% [markdown]
# ---

# %%
# !python -m pip install numpy scipy matplotlib

import main

import numpy as np
import scipy as sp
import matplotlib
import matplotlib.pyplot as plt

# %load_ext memory_profiler

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 1.**
#
# 1. Zaprezentuj na jednym wykresie przebieg funkcji $f(x)$, $f'(x)$ oraz $f''(x)$, w taki sposób, aby na podstawie rysunku można było zgrubnie określić położenie miejsc zerowych funkcji.
#
# 2. Na podstawie analizy wykresu określ przedziały, w których znajdują się miejsca zerowe funkcji $f(x)$.
#
# 3. Odpowiedz w jaki sposób (wykorzystując pierwszą i drugą pochodną) można znaleźć miejsca zerowe funkcji.

# %%
# ===== Twoja implementacja tutaj =====
x = np.arange(-0.5,2,0.05)
plt.figure()

plt.plot(x, main.func(x), label = "f(x)")
plt.plot(x, main.dfunc(x), label = "f'(x)")
plt.plot(x, main.ddfunc(x), label = "f''(x)")
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 2.**
#
# Najprostszą metodą do wyznaczenia miejsc zerowych funkcji nieliniowej jest [metoda bisekcji](https://en.wikipedia.org/wiki/Bisection_method).
#
# Zaimplementuj funkcję *`bisection()`* pamiętając, że gwarancją zbieżności metody bisekcji dla poszukiwania miejsca zerowego funkcji $f(x)$ na odcinku $[a,b]$ są następujące założenia:
#
# 1. Funkcja $f(x)$ jest ciągła w przedziale domkniętym $[a,b]$.
#
# 2. Funkcja $f(x)$ przyjmuje różne znaki na końcach przedziału: $f(a)f(b)<0$.

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 3.**
#
# Bardziej zaawansowaną metodą wyznaczania miejsc zerowych jest [metoda siecznych](https://en.wikipedia.org/wiki/Secant_method), która stanowi rozwinięcie [metody Regula Falsi](https://en.wikipedia.org/wiki/Regula_falsi).
#
# Zaimplementuj funkcję *`secant()`* pamiętając, że gwarancją zbieżności metody siecznych dla poszukiwania miejsca zerowego funkcji $f(x)$ na odcinku $[a,b]$ są następujące założenia:
#
# 1. Funkcja $f(x)$ jest ciągła w przedziale domkniętym $[a,b]$.
#
# 2. Funkcja $f(x)$ przyjmuje różne znaki na końcach przedziału: $f(a)f(b)<0$.
#
# 3. Pierwsza i druga pochodna funkcji $f(x)$ są ciągłe w przedziale domkniętym $[a,b]$.
#
# 4. Pierwsza i druga pochodna funkcji $f(x)$ w przedziale domkniętym $[a, b]$ mają stały znak i są różne od zera.

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 4.**
#
# Inną metodą, wykorzystywaną do poszukiwania miejsc zerowych funkcji, jest [metoda Newtona](https://en.wikipedia.org/wiki/Newton%27s_method), nazywana również metodą stycznych.
#
# **Podpunkt 1.**
#
# Algorytm metody Newtona wykorzystuje wartości pierwszej pochodnej, dlatego przed przystąpieniem do jej implementacji przygotuj pomocniczą funkcję *`difference_quotient()`*, służącą do wyznaczenia wartości ilorazu różnicowego.
#
# <br>
#
# **Podpunkt 2.**
#
# Zaimplementuj funkcję *`newton()`* pamiętając, że gwarancją zbieżności metody Newtona dla poszukiwania miejsca zerowego funkcji $f(x)$ na odcinku $[a,b]$ są następujące założenia:
#
# 1. Funkcja $f(x)$ jest ciągła w przedziale domkniętym $[a,b]$.
#
# 2. Funkcja $f(x)$ przyjmuje różne znaki na końcach przedziału: $f(a)f(b)<0$.
#
# 3. Pierwsza i druga pochodna funkcji $f(x)$ są ciągłe w przedziale domkniętym $[a,b]$.
#
# 4. Pierwsza i druga pochodna funkcji $f(x)$ w przedziale domkniętym $[a, b]$ mają stały znak i są różne od zera.

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 5.**
#
# Dla funkcji $f(x)$ zdefiniowanej w sekcji **Cel zajęć** znajdź miejsca zerowe przy użyciu:
#
# - funkcji [`sp.optimize.root()`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.root.html).
# - funkcji [`sp.optimize.fsolve()`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.fsolve.html).

# %%
# ===== Twoja implementacja tutaj =====

r_root = []

r_root.append(sp.optimize.root(main.func, -1))
r_root.append(sp.optimize.root(main.func, 1))

for root in r_root:
    print(root.x)

r_fsolve = []

r_fsolve.append(sp.optimize.fsolve(main.func, -1)[0])
r_fsolve.append(sp.optimize.fsolve(main.func, 1)[0])


for root in r_fsolve:
    print(root)
# Out:
# [-2.1736944e-17]
# [0.91656258]
# -2.173694401167077e-17
# 0.9165625831056987

# %% [markdown]
# ---

# %% [markdown]
# ### **Zadanie 6.**
#
# Korzystając z przedziałów wyznaczonych w **Zadaniu 1.** znajdź miejsca zerowe funkcji $f(x)$ zdefiniowanej w sekcji **Cel zajęć**, przy użyciu:
#
# - metody bisekcji,
# - metody siecznych,
# - metody Newtona,
#
# z tolerancją równą $1\mathrm{e}{-10}$.
#
# Zbadaj dokładność (względem rozwiązania z **Zadania 5.**) i czas obliczeń metod w zależności od liczby iteracji. Wyniki przedstaw na wykresach.

# %%
# ===== Twoja implementacja tutaj =====

iters = [1]
def bi_root1():
    
    x1, iters[0] = main.bisection(-5, 0.5, main.func, 1e-10, max_iter)
    ax[0][0].scatter(iters[0], abs(x1 - r_fsolve[0]))
  

def bi_root2():
    
    x2, iters[0] = main.bisection(0.5, 5, main.func, 1e-10, max_iter)
    ax[1][0].scatter(iters[0], abs(x2 - r_fsolve[1]))
    




fig, ax = plt.subplots(2,2)

ax[0][0].set_title("x1")
ax[1][0].set_title("x2")

ax[0][1].set_title("x1")
ax[1][1].set_title("x2")
fig.suptitle("Bisection")


for a in ax:
    a[0].grid()
    a[1].grid()
    a[0].set_xlabel("iterations")
    a[1].set_xlabel("iterations")

    a[0].set_ylabel("difference")
    a[1].set_ylabel("average time")

i = [10, 100, 1000, 10000]
for max_iter in i:

    time = %timeit -r 3 -n 3 -o bi_root1()
    ax[0][1].scatter(iters[0], time.average)
    

    time = %timeit -r 3 -n 3 -o bi_root2()
    ax[1][1].scatter(iters[0], time.average)


fig.tight_layout()
plt.show()
# Out:
# 1.01 ms ± 151 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 875 μs ± 177 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 848 μs ± 52.7 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 853 μs ± 24 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 833 μs ± 13.2 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 835 μs ± 7.93 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 873 μs ± 71.9 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 856 μs ± 59.2 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)

# %%
iters = [1]
def sec_root1():
    
    x1, iters[0] = main.secant(-5, 0.5, main.func, 1e-10, max_iter)
    ax[0][0].scatter(iters[0], abs(x1 - r_fsolve[0]))
  

def sec_root2():
    
    x2, iters[0] = main.secant(0.5, 5, main.func, 1e-10, max_iter)
    ax[1][0].scatter(iters[0], abs(x2 - r_fsolve[1]))
    




fig, ax = plt.subplots(2,2)

ax[0][0].set_title("x1")
ax[1][0].set_title("x2")

ax[0][1].set_title("x1")
ax[1][1].set_title("x2")
fig.suptitle("Secant")


for a in ax:
    a[0].grid()
    a[1].grid()
    a[0].set_xlabel("iterations")
    a[1].set_xlabel("iterations")

    a[0].set_ylabel("difference")
    a[1].set_ylabel("average time")

i = [10, 100, 1000, 10000]
for max_iter in i:

    time = %timeit -r 3 -n 3 -o sec_root1()
    ax[0][1].scatter(iters[0], time.average)
    

    time = %timeit -r 3 -n 3 -o sec_root2()
    ax[1][1].scatter(iters[0], time.average)


fig.tight_layout()
plt.show()
# Out:
# 1.85 ms ± 452 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 1.99 ms ± 511 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 4.5 ms ± 934 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 3.01 ms ± 78.3 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 34.3 ms ± 3.7 ms per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 3.35 ms ± 196 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 297 ms ± 3.27 ms per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 3.03 ms ± 48 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)

# %%
iters = [1]

def newton_root1():
    x1, iters[0] = main.newton(main.func, main.dfunc, main.ddfunc, -5, 0.5, 1e-10, max_iter)
    ax[0][0].scatter(iters[0], abs(x1 - r_fsolve[0]))

  
def newton_root2():
    x2, iters[0] = main.newton(main.func, main.dfunc, main.ddfunc, 0.5, 5, 1e-10, max_iter)
    ax[1][0].scatter(iters[0], abs(x2 - r_fsolve[1]))


fig, ax = plt.subplots(2,2)

ax[0][0].set_title("x1")
ax[1][0].set_title("x2")

ax[0][1].set_title("x1")
ax[1][1].set_title("x2")
fig.suptitle("Newton")


for a in ax:
    a[0].grid()
    a[1].grid()
    a[0].set_xlabel("iterations")
    a[1].set_xlabel("iterations")

    a[0].set_ylabel("difference")
    a[1].set_ylabel("average time")

i = [10, 100, 1000, 10000]
for max_iter in i:

    time = %timeit -r 3 -n 3 -o newton_root1()
    ax[0][1].scatter(iters[0], time.average)
    

    time = %timeit -r 3 -n 3 -o newton_root2()
    ax[1][1].scatter(iters[0], time.average)


fig.tight_layout()
plt.show()
# Out:
# 855 μs ± 69.6 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 766 μs ± 12.3 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 792 μs ± 17.1 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 758 μs ± 19.9 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 960 μs ± 250 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 826 μs ± 58 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 797 μs ± 25.6 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)
# 1.04 ms ± 155 μs per loop (mean ± std. dev. of 3 runs, 3 loops each)

# %% [markdown]
# ---

# %% [markdown]
# **Materiały uzupełniające:**
# - [Scipy Lecture Notes](http://www.scipy-lectures.org/index.html)
# - [NumPy for Matlab users](https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html#numpy-for-matlab-users)
# - [Python Tutorial - W3Schools](https://www.w3schools.com/python/default.asp)
# - [NumPy](https://www.numpy.org)
# - [Matplotlib](https://matplotlib.org/)
# - [Anaconda](https://www.anaconda.com/)
# - [Learn Python for Data Science](https://www.datacamp.com/learn-python-with-anaconda?utm_source=Anaconda_download&utm_campaign=datacamp_training&utm_medium=banner)
# - [Learn Python](https://www.learnpython.org/)
# - [Wujek Google](https://google.pl) i [Ciocia Wikipedia](https://pl.wikipedia.org/wiki/Wikipedia:Strona_g%C5%82%C3%B3wna)
